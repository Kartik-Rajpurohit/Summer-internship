# %% [markdown]
# <a href="https://colab.research.google.com/github/Kartik-Rajpurohit/Summer-internship/blob/main/pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import pandas as pd
df = pd.read_csv("/content/review.csv")
df.head()
# Out:
#                                               Review  Rating
# 0  Does absolutely nothing for a LinkedIn beginne...       1
# 1                            Force close(galaxy tab)       1
# 2  Slow and it tries to upload your contacts with...       1
# 3  Add ability to customize the profile and move ...       4
# 4  Good app, but it's a pain that it's not possib...       4

# %%
sns.set(style = 'whitegrid')
plt.figure(figsize = (9,5))
sns.countplot(data = df, x= "Rating")
plt.title('Distribution Of Rating')
plt.xlabel('Rating')
plt.ylabel('Count')
plt.show()

# %%
# !pip install textblob

# %%
from textblob import TextBlob

# %%
def textblob_sentiment_analysis(review):
  sentiment= TextBlob(review).sentiment
  if sentiment.polarity > 0.1 :
    return 'Positive'
  elif sentiment.polarity < -0.1 :
    return 'Negative'
  else :
    return 'Neutral'

# %%
df['Sentiment'] = df['Review'].apply(textblob_sentiment_analysis)

# %%
df.sample(10)
# Out:
#                                                 Review  Rating Sentiment
# 690  The new release 2.0 is far better than the old...       4  Positive
# 463  Was working fine til update. Now force crashes...       3  Positive
# 259                                  Great! Evo, cmod7       5  Positive
# 441                                            Booooo!       1   Neutral
# 695                  Quick and easy to use. Great app!       5  Positive
# 546  Well I am glad to see groups finally included....       1   Neutral
# 315                        Doesn't really do anything.       1  Positive
# 694  Yikes... Talk about losing focus on your targe...       1  Positive
# 230  Obviously you're not listening to your users. ...       1  Negative
# 590                        Need facility to move to SD       3   Neutral

# %%
sentiment_distribution = df['Sentiment'].value_counts()
sentiment_distribution
# Out:
# Sentiment
# Positive    298
# Neutral     297
# Negative    107
# Name: count, dtype: int64
